# %%
import pandas as pd
df=pd.read_csv("/home/harshit/DataSets/Titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import seaborn as sns

sns.stripplot(x='Survived',y='Fare',data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Fare'>

# %%
sns.swarmplot(x='Survived',y='Fare',data=df)
# Out:
# /home/harshit/.local/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 72.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/harshit/.local/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 46.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Survived', ylabel='Fare'>

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
df.drop(columns=['Survived'],inplace=True)

# %%
df
# Out:
#      PassengerId  Pclass                                               Name  \
# 0              1       3                            Braund, Mr. Owen Harris
# 1              2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3       3                             Heikkinen, Miss. Laina
# 3              4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5       3                           Allen, Mr. William Henry
# ..           ...     ...                                                ...
# 886          887       2                              Montvila, Rev. Juozas
# 887          888       1                       Graham, Miss. Margaret Edith
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                              Behr, Mr. Karl Howell
# 890          891       3                                Dooley, Mr. Patrick
#
# ...

# %%
features=df[['Fare']]

# %%
from sklearn.cluster import KMeans

model = KMeans(n_clusters=2)

# %%
predicted=model.fit_predict(features)

# %%
predicted=pd.DataFrame( predicted, columns=['Predicted Labels']  )
predicted.sample(5)
# Out:
#      Predicted Labels
# 667                 1
# 509                 1
# 541                 1
# 389                 1
# 89                  1

# %%
predicted['Predicted Labels'].value_counts()
# Out:
# 1    838
# 0     53
# Name: Predicted Labels, dtype: int64

# %%
temp=df[['Name','Age','Gender','Pclass','Fare']]
temp
# Out:
#                                                   Name   Age  Gender  Pclass  \
# 0                              Braund, Mr. Owen Harris  22.0    male       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female       1
# 2                               Heikkinen, Miss. Laina  26.0  female       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female       1
# 4                             Allen, Mr. William Henry  35.0    male       3
# ..                                                 ...   ...     ...     ...
# 886                              Montvila, Rev. Juozas  27.0    male       2
# 887                       Graham, Miss. Margaret Edith  19.0  female       1
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN  female       3
# 889                              Behr, Mr. Karl Howell  26.0    male       1
# 890                                Dooley, Mr. Patrick  32.0    male       3
#
#         Fare
# 0     7.2500
# 1    71.2833
# ...

# %%
ans=pd.concat([temp,predicted],axis=1)
ans
# Out:
#                                                   Name   Age  Gender  Pclass  \
# 0                              Braund, Mr. Owen Harris  22.0    male       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female       1
# 2                               Heikkinen, Miss. Laina  26.0  female       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female       1
# 4                             Allen, Mr. William Henry  35.0    male       3
# ..                                                 ...   ...     ...     ...
# 886                              Montvila, Rev. Juozas  27.0    male       2
# 887                       Graham, Miss. Margaret Edith  19.0  female       1
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN  female       3
# 889                              Behr, Mr. Karl Howell  26.0    male       1
# 890                                Dooley, Mr. Patrick  32.0    male       3
#
#         Fare  Predicted Labels
# ...

# %%
sns.stripplot(x='Predicted Labels',y='Fare',data=ans)
# Out:
# <AxesSubplot:xlabel='Predicted Labels', ylabel='Fare'>
