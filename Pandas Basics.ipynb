# %%
import pandas as pd

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=pd.read_csv("/home/harshit/Desktop/Titanic.csv")

# %%
#names of columns 


df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#see number of rows as number of columns


df.shape
# Out:
# (891, 12)

# %% [markdown]
# """
# rows----->records
#
# columns------>features/attributes of the data
# """

# %%
#random samples (this is a function)



df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 354          355         0       3              Yousif, Mr. Wazli    male
# 786          787         1       3      Sjoblom, Miss. Anna Sofia  female
# 271          272         1       3   Tornquist, Mr. William Henry    male
# 417          418         1       2  Silven, Miss. Lyyli Karoliina  female
# 762          763         1       3          Barah, Mr. Hanna Assi    male
#
#       Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 354   NaN      0      0     2647   7.2250   NaN        C
# 786  18.0      0      0  3101265   7.4958   NaN        S
# 271  25.0      0      0     LINE   0.0000   NaN        S
# 417  18.0      0      2   250652  13.0000   NaN        S
# 762  20.0      0      0     2663   7.2292   NaN        C

# %%
#first N rows from the data


df.head(4) #first 4 rows from the given data set
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
#how to locate rows?


#find a single row by its number


#765


df.loc[  [765] ,       ]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 765          766         1       1  Hogeboom, Mrs. John C (Anna Andrews)
#
#         Sex   Age  SibSp  Parch Ticket     Fare Cabin Embarked
# 765  female  51.0      1      0  13502  77.9583   D11        S

# %%
#765th row, Name and Fare column


df.loc[      [765]  ,  ['Name', 'Fare']      ]
# Out:
#                                      Name     Fare
# 765  Hogeboom, Mrs. John C (Anna Andrews)  77.9583

# %%
#765th row, Name and Fare column


df.loc[      765      ] #series data type
# Out:
# PassengerId                                     766
# Survived                                          1
# Pclass                                            1
# Name           Hogeboom, Mrs. John C (Anna Andrews)
# Sex                                          female
# Age                                              51
# SibSp                                             1
# Parch                                             0
# Ticket                                        13502
# Fare                                        77.9583
# Cabin                                           D11
# Embarked                                          S
# Name: 765, dtype: object

# %%
#multiple rows

#765 and 560

df.loc[      [ 765, 560 ]  ,  ['Name', 'Fare']      ]
# Out:
#                                      Name     Fare
# 765  Hogeboom, Mrs. John C (Anna Andrews)  77.9583
# 560              Morrow, Mr. Thomas Rowan   7.7500

# %%
df.loc[      [ 765, 560,19,86,167,190 ]  ,  ['Name', 'Fare']      ]
# Out:
#                                                 Name     Fare
# 765             Hogeboom, Mrs. John C (Anna Andrews)  77.9583
# 560                         Morrow, Mr. Thomas Rowan   7.7500
# 19                           Masselmani, Mrs. Fatima   7.2250
# 86                            Ford, Mr. William Neal  34.3750
# 167  Skoog, Mrs. William (Anna Bernhardina Karlsson)  27.9000
# 190                              Pinsky, Mrs. (Rosa)  13.0000

# %%
# df.loc[     :   , ['Name', 'Fare']      ]

# %%
#sequence of rows

#all rows between 1 and 10(both inclusive)

df.loc[      1:10  ,  ['Name', 'Fare']      ]
# Out:
#                                                  Name     Fare
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833
# 2                              Heikkinen, Miss. Laina   7.9250
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000
# 4                            Allen, Mr. William Henry   8.0500
# 5                                    Moran, Mr. James   8.4583
# 6                             McCarthy, Mr. Timothy J  51.8625
# 7                      Palsson, Master. Gosta Leonard  21.0750
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  11.1333
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  30.0708
# 10                    Sandstrom, Miss. Marguerite Rut  16.7000

# %%
#show columns of my choice


df[     [  'Name','Age','Fare'  ]     ]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#find out the number of missing values in each column


df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#chaining of commands

#show name and age of first 5 rows

df.head(5)[ ['Name','Age'] ]
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                           Allen, Mr. William Henry  35.0

# %%
#show Names of 8 random records
df.sample(8)[ ['Name'] ]
# Out:
#                                           Name
# 468                         Scanlan, Mr. James
# 883              Banfield, Mr. Frederick James
# 347  Davison, Mrs. Thomas Henry (Mary E Finck)
# 88                  Fortune, Miss. Mabel Helen
# 413             Cunningham, Mr. Alfred Fleming
# 510                   Daly, Mr. Eugene Patrick
# 479                   Hirvonen, Miss. Hildur E
# 153            van Billiard, Mr. Austin Blyler

# %%
#show Names of 8 random records
df.sample(8)[ 'Name' ]
# Out:
# 46                           Lennon, Mr. Denis
# 580                Christy, Miss. Julie Rachel
# 369              Aubart, Mme. Leontine Pauline
# 789                   Guggenheim, Mr. Benjamin
# 787                  Rice, Master. George Hugh
# 100                    Petranec, Miss. Matilda
# 579                        Jussila, Mr. Eiriik
# 830    Yasbeck, Mrs. Antoni (Selini Alexander)
# Name: Name, dtype: object

# %%
#show names and age of n number of rows and print the missing value count of each

df.sample(8)[[ "Name",'Age' ]].isna().sum()
# Out:
# Name    0
# Age     2
# dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['Fare']].sum() #sum of all the values
# Out:
# Fare    28693.9493
# dtype: float64

# %%
df[['Fare']].mean() #average of all the values
# Out:
# Fare    32.204208
# dtype: float64

# %%
df[['Fare']].min() #minimum of all the values
# Out:
# Fare    0.0
# dtype: float64

# %%
#average Age and average Fare in one command?

df[['Age','Fare']].mean()
# Out:
# Age     29.699118
# Fare    32.204208
# dtype: float64

# %%
#aggregation operations
"""

apply multiple aggregations on one or more than one column at the same time

"""

df[['Age','Fare']].agg(  ['mean','sum']  )
# Out:
#                Age          Fare
# mean     29.699118     32.204208
# sum   21205.170000  28693.949300

# %%
df[['Age','Fare']].agg(  ['mean','sum','min','max']  )
# Out:
#                Age          Fare
# mean     29.699118     32.204208
# sum   21205.170000  28693.949300
# min       0.420000      0.000000
# max      80.000000    512.329200

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df[['Age']].quantile(0.9) #90 percentile
# Out:
# Age    50.0
# Name: 0.9, dtype: float64

# %%
#apply different aggregates on different columns


#sum of fare and average age in the same command

df[['Age','Fare']].agg( {  'Age':'mean' , 'Fare':'sum'  }  )
# Out:
# Age        29.699118
# Fare    28693.949300
# dtype: float64

# %%
#sum of fare and min, max and average age in the same command

df[['Age','Fare']].agg( {  'Age':['mean','min','max'] , 'Fare':'sum'  }  )
# Out:
#             Age        Fare
# max   80.000000         NaN
# mean  29.699118         NaN
# min    0.420000         NaN
# sum         NaN  28693.9493

# %%
#calculate the average age of female passengers in the dataset(filtering!)





#average fare collected from Pclass 1 and Pclass 2 passengers(filtering)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
condition = ( df ['Sex'] == 'female'  )


df[   condition  ]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#column data type information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#pclass 1 OR pclass 2


condition = ( df ['Pclass'] == 1  ) | (df ['Pclass'] == 2)
df[condition]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 9             10         1       2
# 11            12         1       1
# ..           ...       ...     ...
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#age > 25 and gender is female

condition=(df['Age'] > 25 )  & (df['Sex']=='female')
df[condition]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 866          867         1       2
# 871          872         1       1
# 874          875         1       2
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#female passengers above the age of 20 from Pclass 3

condition = ( df ['Age'] > 25 ) & (df ['Sex'] == 'female') & (df ['Pclass'] == 3)
df[condition]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 18            19         0       3
# 25            26         1       3
# 40            41         0       3
# 79            80         1       3
# 85            86         1       3
# 100          101         0       3
# 132          133         0       3
# 167          168         0       3
# 216          217         1       3
# 251          252         0       3
# 254          255         0       3
# 255          256         1       3
# 276          277         0       3
# 279          280         1       3
# 315          316         1       3
# 328          329         1       3
# 362          363         0       3
# 396          397         0       3
# 423          424         0       3
# 483          484         1       3
# 503          504         0       3
# 534          535         0       3
# 559          560         1       3
# ...

# %%
#female passengers between the age of 20 to 25(both included) from Pclass 3
condition = ( df ['Age'].between(20,25) ) & (df ['Sex'] == 'female') & (df ['Pclass'] == 3)
df[condition]
# Out:
#      PassengerId  Survived  Pclass  \
# 106          107         1       3
# 113          114         0       3
# 141          142         1       3
# 142          143         1       3
# 246          247         0       3
# 289          290         1       3
# 293          294         0       3
# 376          377         1       3
# 394          395         1       3
# 402          403         0       3
# 404          405         0       3
# 436          437         0       3
# 474          475         0       3
# 501          502         0       3
# 554          555         1       3
# 649          650         1       3
# 729          730         0       3
# 816          817         0       3
# 858          859         1       3
# 882          883         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 106                   Salkjelsvik, Miss. Anna Kristine  female  21.0      0
# ...

# %%
#show records of passengers who paid fare between 100 to 200

condition=(df["Fare"].between(100,200))
df[condition]
# Out:
#      PassengerId  Survived  Pclass  \
# 31            32         1       1
# 195          196         1       1
# 215          216         1       1
# 268          269         1       1
# 269          270         1       1
# 297          298         0       1
# 305          306         1       1
# 306          307         1       1
# 307          308         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 332          333         0       1
# 334          335         1       1
# 337          338         1       1
# 373          374         0       1
# 390          391         1       1
# 393          394         1       1
# 435          436         1       1
# 498          499         0       1
# 505          506         0       1
# 537          538         1       1
# 544          545         0       1
# 550          551         1       1
# 581          582         1       1
# ...

# %%
#records of passengers who age is 20, 28 , 34 or 18

#lengthy and verbose way
condition=(df["Age"] == 20 ) | (df["Age"] == 28 ) | (df["Age"] == 34 ) | (df["Age"] == 18 )

# %%
condition=(df['Age'].isin(  [20,28,34,18]  )   ) #simple and elegant
df[condition]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 12            13         0       3         Saundercock, Mr. William Henry
# 21            22         1       2                  Beesley, Mr. Lawrence
# 23            24         1       1           Sloper, Mr. William Thompson
# 34            35         0       1                Meyer, Mr. Edgar Joseph
# 38            39         0       3     Vander Planke, Miss. Augusta Maria
# ..           ...       ...     ...                                    ...
# 848          849         0       2                      Harper, Rev. John
# 855          856         1       3             Aks, Mrs. Sam (Leah Rosen)
# 874          875         1       2  Abelson, Mrs. Samuel (Hannah Wizosky)
# 876          877         0       3          Gustafsson, Mr. Alfred Ossian
# 883          884         0       2          Banfield, Mr. Frederick James
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
#locate the rows 17 , 89 and 20 and show names of passengers in those rows

# %%
#find out the maximum fare paid by passenger. 
#Show record of these passengers(multiple passengers have paid max fare)


condition=( df['Fare'] == df['Fare'].max() )

df[condition][['Name of Passenger']]
# Out:
#                       Name of Passenger
# 258                    Ward, Miss. Anna
# 679  Cardeza, Mr. Thomas Drake Martinez
# 737              Lesurer, Mr. Gustave J

# %%
#find the records of passengers in the age group of 20-50 who paid a fare of over 100 and travelled pclass 2 or 3

# %%
#find the total fare collected from male passengers in Pclass 3

# %%
#find the total number of passengers in Pclass 2

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.rename(  columns={'Name':  'Name of Passenger'},inplace=True  )

# %%
df.rename(  columns={'Name of Passenger':  'XYZ'}  )
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                    XYZ     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                      Name of Passenger     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#if number of unique categories are less than or equal to 5----> categorical

#more than 5 variations--->continuous

# %%
#how many unique values do you have???

df['Sex'].unique() #categorical
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
df['Fare'].unique()
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#         31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,  18.    ,
#          7.225 ,  26.    ,   8.0292,  35.5   ,  31.3875, 263.    ,
#          7.8792,   7.8958,  27.7208, 146.5208,   7.75  ,  10.5   ,
#         82.1708,  52.    ,   7.2292,  11.2417,   9.475 ,  21.    ,
#         41.5792,  15.5   ,  21.6792,  17.8   ,  39.6875,   7.8   ,
#         76.7292,  61.9792,  27.75  ,  46.9   ,  80.    ,  83.475 ,
#         27.9   ,  15.2458,   8.1583,   8.6625,  73.5   ,  14.4542,
#         56.4958,   7.65  ,  29.    ,  12.475 ,   9.    ,   9.5   ,
#          7.7875,  47.1   ,  15.85  ,  34.375 ,  61.175 ,  20.575 ,
#         34.6542,  63.3583,  23.    ,  77.2875,   8.6542,   7.775 ,
#         24.15  ,   9.825 ,  14.4583, 247.5208,   7.1417,  22.3583,
#          6.975 ,   7.05  ,  14.5   ,  15.0458,  26.2833,   9.2167,
# ...

# %%
df['Age'].unique() #continuous
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
#how many passengers are present in Pclass 1 , 2 and 3?


#categorical attributes

df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df['Sex'].value_counts( normalize=True  )
# Out:
# male      0.647587
# female    0.352413
# Name: Sex, dtype: float64

# %%
#grouping


#data of pclass 1 , 2 and 3, average fare
condition1=(df['Pclass']==1)
condition2=(df['Pclass']==2)
condition3=(df['Pclass']==3)


df[condition1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                      Name of Passenger     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[condition2]
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 15            16         1       2
# 17            18         1       2
# 20            21         0       2
# 21            22         1       2
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
#
#                                 Name of Passenger     Sex   Age  SibSp  Parch  \
# 9             Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1      0
# 15               Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0      0
# 17                   Williams, Mr. Charles Eugene    male   NaN      0      0
# 20                           Fynney, Mr. Joseph J    male  35.0      0      0
# 21                          Beesley, Mr. Lawrence    male  34.0      0      0
# ...

# %%
#average fare in each Pclass

df.groupby( ['Pclass']  )[['Fare']].mean()
# Out:
#              Fare
# Pclass
# 1       84.154687
# 2       20.662183
# 3       13.675550

# %%
df[['Fare']].mean()
# Out:
# Fare    32.204208
# dtype: float64

# %%
df['Fare'].mean()
# Out:
# 32.204207968574636

# %%
#total fare according to gender

df.groupby( ['Sex']  )[['Fare']].sum()
# Out:
#               Fare
# Sex
# female  13966.6628
# male    14727.2865

# %%
#reset_index
df.groupby( ['Sex','Pclass']  )[['Fare']].sum().reset_index()
# Out:
#       Sex  Pclass       Fare
# 0  female       1  9975.8250
# 1  female       2  1669.7292
# 2  female       3  2321.1086
# 3    male       1  8201.5875
# 4    male       2  2132.1125
# 5    male       3  4393.5865

# %%
temp = df.groupby( ['Sex','Pclass']  ) #multiple filter 


temp.groups.keys() #which groups were formed?
# Out:
# dict_keys([('female', 1), ('female', 2), ('female', 3), ('male', 1), ('male', 2), ('male', 3)])

# %%
#see records from a particular group???


temp.get_group(('female', 3)) #equivalent to filtering for female and pclass 2
# Out:
#      PassengerId  Survived                                  Name of Passenger  \
# 2              3         1                             Heikkinen, Miss. Laina
# 8              9         1  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10            11         1                    Sandstrom, Miss. Marguerite Rut
# 14            15         0               Vestrom, Miss. Hulda Amanda Adolfina
# 18            19         0  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# ..           ...       ...                                                ...
# 863          864         0                  Sage, Miss. Dorothy Edith "Dolly"
# 875          876         1                   Najib, Miss. Adele Kiamie "Jane"
# 882          883         0                       Dahlberg, Miss. Gerda Ulrika
# 885          886         0               Rice, Mrs. William (Margaret Norton)
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
#number of groups

temp.ngroups
# Out:
# 6

# %%
temp[['Age','Fare']].agg(  ['min','max']  )
# Out:
#                 Age           Fare
#                 min   max      min       max
# Sex    Pclass
# female 1       2.00  63.0  25.9292  512.3292
#        2       2.00  57.0  10.5000   65.0000
#        3       0.75  63.0   6.7500   69.5500
# male   1       0.92  80.0   0.0000  512.3292
#        2       0.67  70.0   0.0000   73.5000
#        3       0.42  74.0   0.0000   69.5500

# %%
#min fare of females in Pclass 2
temp[['Age','Fare']].agg(  ['min','max']  ).loc[  [('female',2)],   [('Fare','min')]   ]
# Out:
#                Fare
#                 min
# Sex    Pclass
# female 2       10.5

# %%
#min fare of females in Pclass 2

temp.get_group(   ('female', 2)  )[['Fare']].min()
# Out:
# Fare    10.5
# dtype: float64

# %%
#6.75000--------> Minimum Fare paid by Female passengers in Pclass 3


#NOT RECOMMENDED way of obtaining the result

condition=(df['Pclass']==3 ) & (df['Sex']=='female')

df[  condition  ][['Fare']].agg(['min'])
# Out:
#      Fare
# min  6.75

# %% [markdown]
# """
# #group data first
#
# #extract the relevant column
#
# #apply an operation
# """

# %%
#group data by Pclass and Embarked. Find average age in each group


#1 line syntax

df.groupby(  ['Pclass','Embarked']  )[['Age']].mean()
# Out:
#                        Age
# Pclass Embarked
# 1      C         38.027027
#        Q         38.500000
#        S         38.152037
# 2      C         22.766667
#        Q         43.500000
#        S         30.386731
# 3      C         20.741951
#        Q         25.937500
#        S         25.696552

# %%
temp=df.groupby(  ['Pclass','Embarked']  )



temp[['Age']].mean()
# Out:
#                        Age
# Pclass Embarked
# 1      C         38.027027
#        Q         38.500000
#        S         38.152037
# 2      C         22.766667
#        Q         43.500000
#        S         30.386731
# 3      C         20.741951
#        Q         25.937500
#        S         25.696552

# %%
#find out the minimum, maximum and average fare by each category of Pclass

# %%
#find the total fare paid by passengers grouped according to their gender, Pclass and embarked location


df.groupby(['Pclass','Sex','Embarked'])[['Fare']].sum()
# Out:
#                              Fare
# Pclass Sex    Embarked
# 1      female C         4972.5333
#               Q           90.0000
#               S         4753.2917
#        male   C         3928.5417
#               Q           90.0000
#               S         4183.0458
# 2      female C          176.8792
#               Q           24.7000
#               S         1468.1500
#        male   C          254.2125
#               Q           12.3500
#               S         1865.5500
# 3      female C          337.9833
#               Q          340.1585
#               S         1642.9668
#        male   C          402.1462
#               Q          465.0458
#               S         3526.3945

# %%
# 0 to 80


#average fare paid in every age bracket(  0 -10 , 10-20, 20-30,30-40 .......)
import numpy as np #numpy


                                      #start,end,interval
    
bins=pd.cut(  df['Age'],  np.arange( 0,90,10  ) )  

df.groupby(  bins  )[['Fare']].mean()
# Out:
#                Fare
# Age
# (0, 10]   30.434439
# (10, 20]  29.529531
# (20, 30]  28.306719
# (30, 40]  42.496100
# (40, 50]  41.163181
# (50, 60]  44.774802
# (60, 70]  45.910782
# (70, 80]  25.936680

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                      Name of Passenger     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#sort this data in ascending order of age


df.sort_values(by=['Age'],ascending=True)
# Out:
#      PassengerId  Survived  Pclass                         Name of Passenger  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
#sort this data in descending order of age


#select * from df order by Age Desc
df.sort_values(by=['Age'],ascending=False)
# Out:
#      PassengerId  Survived  Pclass                         Name of Passenger  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
d1={
    
    "Name":[ 'Arun',"Ajay","Dhavan", "Leonard", "Jai" ],
    "Age" :[  20, 19, 24, 39, 39  ],
    "Salary": [  18000, 21000, 21000, 17000, 34000  ]
}


df1=pd.DataFrame(  d1 )

# %%
df1
# Out:
#       Name  Age  Salary
# 0     Arun   20   18000
# 1     Ajay   19   21000
# 2   Dhavan   24   21000
# 3  Leonard   39   17000
# 4      Jai   39   34000

# %%
df1.sort_values(by='Age' ) #ascending order
# Out:
#       Name  Age  Salary
# 1     Ajay   19   21000
# 0     Arun   20   18000
# 2   Dhavan   24   21000
# 3  Leonard   39   17000
# 4      Jai   39   34000

# %%
#based on Names

df1.sort_values(by='Name' ) #alphabetical order
# Out:
#       Name  Age  Salary
# 1     Ajay   19   21000
# 0     Arun   20   18000
# 2   Dhavan   24   21000
# 4      Jai   39   34000
# 3  Leonard   39   17000

# %%
#based on Age or Salary

df1.sort_values(by=['Age','Salary'] ) #ascending order
# Out:
#       Name  Age  Salary
# 1     Ajay   19   21000
# 0     Arun   20   18000
# 2   Dhavan   24   21000
# 3  Leonard   39   17000
# 4      Jai   39   34000

# %%
#select * from df1 order by Age Asc, salary DESC;

df1.sort_values(by=['Age','Salary'], ascending=[ True , False ] ) #ascending order of Age and descending order of salary
# Out:
#       Name  Age  Salary
# 1     Ajay   19   21000
# 0     Arun   20   18000
# 2   Dhavan   24   21000
# 4      Jai   39   34000
# 3  Leonard   39   17000

# %%
import seaborn as sns #visual charts , matplotlib

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
sns.countplot( x='Sex',data=df  )
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.countplot( x='Sex',data=df,hue='Pclass'  ) #2 parameters
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.catplot( row='Sex', col='Embarked',data=df ,kind='count', x='Pclass') #2 parameters

# %%
#relationship between 2 continuous attributes

sns.scatterplot(   x='Age',y='Fare',data=df  )
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
#relationship between 2 continuous attributes

sns.scatterplot(   x='Age',y='Fare',data=df, hue='Sex'  )
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
#seaborn global settings

sns.set_style('dark') #darkgrid, dark, white, whitegrid

# %%
sns.scatterplot(   x='Age',y='Fare',data=df, hue='Sex'  )
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
sns.set_style('darkgrid') #darkgrid, dark, white, whitegrid

# %%
sns.scatterplot(   x='Age',y='Fare',data=df, hue='Sex'  )
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(   x='Age',y='Fare',data=df, hue='Sex' ,palette='rainbow' )
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(   x='Age',y='Fare',data=df, hue='Sex' ,palette='summer' )
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(   x='Age',y='Fare',data=df, hue='Sex' ,palette='winter' )
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(   x='Age',y='Fare',data=df, hue='Sex' ,palette='autumn' )
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(   x='Age',y='Fare',data=df, hue='Sex' ,palette='magma' )
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
#please generate a graph

#create a graph of count of passengers categorized by Embarked location distributed by Pclass!
sns.countplot(x='Embarked',data=df,hue='Pclass')
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %%
#distribution of data in terms of percentiles or quantiles


#boxplot! (box or whisker plot)

#continuous
sns.boxplot( y='Age',data=df ) #IQR???
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
#one continuous & one categorical attribute
sns.boxplot( y='Age',x='Sex',data=df )
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
#one continuous & one categorical attribute
sns.boxplot( y='Age',x='Sex',data=df,hue='Pclass' )
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sns.lineplot(x='Age',y='Fare',data=df) #timeseries data(financial domain)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
sns.lineplot(x='Age',y='Fare',data=df,hue='Pclass',palette='magma') #timeseries data(financial domain)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
temp=pd.read_csv('/home/harshit/DataSets/YESBANK.csv')
temp
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2017-12-11  313.500000  315.799988  310.600006  311.600006  300.880615
# 1    2017-12-12  312.000000  312.000000  305.899994  306.799988  296.245758
# 2    2017-12-13  306.350006  307.350006  301.049988  301.899994  291.514282
# 3    2017-12-14  303.899994  304.649994  301.750000  303.899994  293.445526
# 4    2017-12-15  307.000000  317.450012  307.000000  315.899994  305.032715
# ..          ...         ...         ...         ...         ...         ...
# 733  2020-12-02   15.700000   15.900000   14.850000   15.450000   15.450000
# 734  2020-12-03   15.650000   15.800000   15.250000   15.450000   15.450000
# 735  2020-12-04   15.600000   15.600000   15.050000   15.350000   15.350000
# 736  2020-12-07   15.650000   15.850000   15.500000   15.750000   15.750000
# 737  2020-12-08   16.000000   17.299999   16.000000   17.299999   17.299999
#
#           Volume
# 0      4416465.0
# 1      5457103.0
# ...

# %%
sns.lineplot(x='Open',y='Close',data=temp)
# Out:
# <AxesSubplot:xlabel='Open', ylabel='Close'>
